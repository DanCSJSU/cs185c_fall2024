# %% [markdown]
# # Homework 3: Visualizing Data with Movies
#
# Name:
#
# Date:
#
# #### Overview
# In this homework, you'll create a movie visualization of a model parameter such as temperature, salinity, velocity, or any other field which may be of interest to you.
#
# As an example, I've provided a movie of circulation in the Equatorial Pacific from the NASA ECCO Version 5 State Estimate. For the purposes of this visualization, I subsetted the Equatorial Pacific is the region between 155-75$^{\circ}$W and $\pm$20$^{\circ}$N.
#
# #### Import Modules
# Import the modules required to access data from netCDF files, plot it, and stitch panels together into a movie:

# %%
# import modules here
import os
import numpy as np
import matplotlib.pyplot as plt
import netCDF4 as nc4
import moviepy.video.io.ImageSequenceClip
import xarray as xr

# %% [markdown]
# ## Part 1: Download Data
# To begin this exercise, download all of the available data for your variable of interest over the timespan of interest.
#
# For the example provided, I've used daily sea surface temperature data for a given year (2015) from the ECCO Version 5 Alpha output [HERE](https://ecco.jpl.nasa.gov/drive/files/Version5/Alpha/latlon_daily/SST.nc).
#
# To obtain your data, use the [Downloading ECCO Data](https://github.com/ProfMikeWood/ocean_modeling_book/blob/main/tools/Downloading%20ECCO%20Data.ipynb) notebook provided with the course notes. Be sure to edit the fields to obtain the correct data.

# %%
# define the path to the data folder
data_folder = 'C:\\Users\\Daniel\\Desktop\\185data\\Version4\\Release4\\interp_monthly\\THETA'

# %% [markdown]
# ## Part 2: Create a Single Plot of Sea Surface Temperature
# Before making a movie, its useful to fine tune a single plot to get the details right. Once you've got your plot lookin' good, you can loop through all of the data to generate the panels of your movie.
#
# Here, make a plot of one variable field.
#
# Begin by reading in the longitude, latitude, and SST fields from the netCDF file:

# %%
# read in the data
file_path = 'C:\\Users\\Daniel\\Desktop\\185data\\Version4\\Release4\\interp_monthly\\THETA\\THETA_2015_01.nc'

def plot_panel(year, month, day, data_folder, output_folder):
    file_name = f'THETA_{year}_{month:02d}.nc'
    file_path = os.path.join(data_folder, file_name)
    
ds = xr.open_dataset(file_path)

longitude = ds['longitude'].values
latitude = ds['latitude'].values
theta = ds['THETA'].values

# %% [markdown]
# Next, find the locations of the longitude and latitude bounds within the global grid for your region of interest:

# %%
# define the longitude/latitude bounds
min_lon = -80
max_lon = -10
min_lat = 0
max_lat = 60

# compute the min/max row/col in the data grid
min_row = np.searchsorted(latitude, min_lat)
max_row = np.searchsorted(latitude, max_lat) 
min_col = np.searchsorted(longitude, min_lon)
max_col = np.searchsorted(longitude, max_lon)

# %% [markdown]
# Use the row and column bounds to subset the longitude, latitude, and your variable:

# %%
# subset the data
subset_longitude = longitude[min_col:max_col]
subset_latitude = latitude[min_row:max_row]
subset_theta = theta[0, :, min_row:max_row, min_col:max_col]

# %% [markdown]
# Finally, make a plot with your subsetted data. For the plot specification, you can use any colormap, data range, and format as you like.
#
# For my example, I find that the temperature plot looks nice with a figure size of (8,4), a turbo colormap, and a data range of 20-31. However, you are encouraged to format your plot to your tastes.

# %%
# make your figure here
fig, ax = plt.subplots(figsize=(8, 4))
c = ax.pcolormesh(subset_longitude, subset_latitude, subset_theta[0, :, :], cmap='turbo', vmin=5, vmax=30)

fig.colorbar(c, ax=ax, label='Surface Temperature (C*)')

ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_title(f'Sea Surface Temperature in Mid-Atlantic Ocean ({year}-{month:02d}-{day:02d})')

output_file = os.path.join(output_folder, f'SST_{year}_{month:02d}_{day:02d}.png')

plt.savefig(output_file)


data_folder = 'C:\\Users\\Daniel\\Desktop\\185data\\Version4\\Release4\\interp_monthly\\THETA'
output_folder = 'C:\\Users\Daniel\\Desktop\\185output'

plt.show()

# %% [markdown]
# ## Part 3: Formulate a Plotting Function
# When you are happy with your plot, make your code into a function that will take the year, month, and day as inputs, and output the figure into a given directory.

# %% [markdown]
# Once the function is complete, use it to loop through all of the data to make a plot for each day of the year. The following lines of code will form the panels of a data visualization movie when using daily data. If you are using monthly data, update accordingly:

# %%
# Loop through the data and make a plot for each day
data_folder = 'C:\\Users\\Daniel\\Desktop\\185data\\Version4\\Release4\\interp_monthly\\THETA'
year = 2015
for month in range(1, 13):
    if month in [1, 3, 5, 7, 8, 10, 12]:
        n_days = 31
    elif month in [4, 6, 9, 11]:
        n_days = 30
    else:
        if year % 4 == 0:
            n_days = 29
        else:
            n_days = 28
    for day in range(1, n_days + 1):
        print(f"Processing {year}-{month:02d}-{day:02d}")
        plot_panel(year, month, day, data_folder, output_folder)
# Out:
# Processing 2015-01-01
# Processing 2015-01-02
# Processing 2015-01-03
# Processing 2015-01-04
# Processing 2015-01-05
# Processing 2015-01-06
# Processing 2015-01-07
# Processing 2015-01-08
# Processing 2015-01-09
# Processing 2015-01-10
# Processing 2015-01-11
# Processing 2015-01-12
# Processing 2015-01-13
# Processing 2015-01-14
# Processing 2015-01-15
# Processing 2015-01-16
# Processing 2015-01-17
# Processing 2015-01-18
# Processing 2015-01-19
# Processing 2015-01-20
# Processing 2015-01-21
# Processing 2015-01-22
# Processing 2015-01-23
# Processing 2015-01-24
# Processing 2015-01-25
# Processing 2015-01-26
# Processing 2015-01-27
# Processing 2015-01-28
# Processing 2015-01-29
# Processing 2015-01-30
# Processing 2015-01-31
# Processing 2015-02-01
# Processing 2015-02-02
# Processing 2015-02-03
# Processing 2015-02-04
# Processing 2015-02-05
# Processing 2015-02-06
# Processing 2015-02-07
# Processing 2015-02-08
# Processing 2015-02-09
# Processing 2015-02-10
# Processing 2015-02-11
# Processing 2015-02-12
# Processing 2015-02-13
# Processing 2015-02-14
# Processing 2015-02-15
# Processing 2015-02-16
# Processing 2015-02-17
# Processing 2015-02-18
# Processing 2015-02-19
# Processing 2015-02-20
# Processing 2015-02-21
# Processing 2015-02-22
# Processing 2015-02-23
# Processing 2015-02-24
# Processing 2015-02-25
# Processing 2015-02-26
# Processing 2015-02-27
# Processing 2015-02-28
# Processing 2015-03-01
# Processing 2015-03-02
# Processing 2015-03-03
# Processing 2015-03-04
# Processing 2015-03-05
# Processing 2015-03-06
# Processing 2015-03-07
# Processing 2015-03-08
# Processing 2015-03-09
# Processing 2015-03-10
# Processing 2015-03-11
# Processing 2015-03-12
# Processing 2015-03-13
# Processing 2015-03-14
# Processing 2015-03-15
# Processing 2015-03-16
# Processing 2015-03-17
# Processing 2015-03-18
# Processing 2015-03-19
# Processing 2015-03-20
# Processing 2015-03-21
# Processing 2015-03-22
# Processing 2015-03-23
# Processing 2015-03-24
# Processing 2015-03-25
# Processing 2015-03-26
# Processing 2015-03-27
# Processing 2015-03-28
# Processing 2015-03-29
# Processing 2015-03-30
# Processing 2015-03-31
# Processing 2015-04-01
# Processing 2015-04-02
# Processing 2015-04-03
# Processing 2015-04-04
# Processing 2015-04-05
# Processing 2015-04-06
# Processing 2015-04-07
# Processing 2015-04-08
# Processing 2015-04-09
# Processing 2015-04-10
# Processing 2015-04-11
# Processing 2015-04-12
# Processing 2015-04-13
# Processing 2015-04-14
# Processing 2015-04-15
# Processing 2015-04-16
# Processing 2015-04-17
# Processing 2015-04-18
# Processing 2015-04-19
# Processing 2015-04-20
# Processing 2015-04-21
# Processing 2015-04-22
# Processing 2015-04-23
# Processing 2015-04-24
# Processing 2015-04-25
# Processing 2015-04-26
# Processing 2015-04-27
# Processing 2015-04-28
# Processing 2015-04-29
# Processing 2015-04-30
# Processing 2015-05-01
# Processing 2015-05-02
# Processing 2015-05-03
# Processing 2015-05-04
# Processing 2015-05-05
# Processing 2015-05-06
# Processing 2015-05-07
# Processing 2015-05-08
# Processing 2015-05-09
# Processing 2015-05-10
# Processing 2015-05-11
# Processing 2015-05-12
# Processing 2015-05-13
# Processing 2015-05-14
# Processing 2015-05-15
# Processing 2015-05-16
# Processing 2015-05-17
# Processing 2015-05-18
# Processing 2015-05-19
# Processing 2015-05-20
# Processing 2015-05-21
# Processing 2015-05-22
# Processing 2015-05-23
# Processing 2015-05-24
# Processing 2015-05-25
# Processing 2015-05-26
# Processing 2015-05-27
# Processing 2015-05-28
# Processing 2015-05-29
# Processing 2015-05-30
# Processing 2015-05-31
# Processing 2015-06-01
# Processing 2015-06-02
# Processing 2015-06-03
# Processing 2015-06-04
# Processing 2015-06-05
# Processing 2015-06-06
# Processing 2015-06-07
# Processing 2015-06-08
# Processing 2015-06-09
# Processing 2015-06-10
# Processing 2015-06-11
# Processing 2015-06-12
# Processing 2015-06-13
# Processing 2015-06-14
# Processing 2015-06-15
# Processing 2015-06-16
# Processing 2015-06-17
# Processing 2015-06-18
# Processing 2015-06-19
# Processing 2015-06-20
# Processing 2015-06-21
# Processing 2015-06-22
# Processing 2015-06-23
# Processing 2015-06-24
# Processing 2015-06-25
# Processing 2015-06-26
# Processing 2015-06-27
# Processing 2015-06-28
# Processing 2015-06-29
# Processing 2015-06-30
# Processing 2015-07-01
# Processing 2015-07-02
# Processing 2015-07-03
# Processing 2015-07-04
# Processing 2015-07-05
# Processing 2015-07-06
# Processing 2015-07-07
# Processing 2015-07-08
# Processing 2015-07-09
# Processing 2015-07-10
# Processing 2015-07-11
# Processing 2015-07-12
# Processing 2015-07-13
# Processing 2015-07-14
# Processing 2015-07-15
# Processing 2015-07-16
# Processing 2015-07-17
# Processing 2015-07-18
# Processing 2015-07-19
# Processing 2015-07-20
# Processing 2015-07-21
# Processing 2015-07-22
# Processing 2015-07-23
# Processing 2015-07-24
# Processing 2015-07-25
# Processing 2015-07-26
# Processing 2015-07-27
# Processing 2015-07-28
# Processing 2015-07-29
# Processing 2015-07-30
# Processing 2015-07-31
# Processing 2015-08-01
# Processing 2015-08-02
# Processing 2015-08-03
# Processing 2015-08-04
# Processing 2015-08-05
# Processing 2015-08-06
# Processing 2015-08-07
# Processing 2015-08-08
# Processing 2015-08-09
# Processing 2015-08-10
# Processing 2015-08-11
# Processing 2015-08-12
# Processing 2015-08-13
# Processing 2015-08-14
# Processing 2015-08-15
# Processing 2015-08-16
# Processing 2015-08-17
# Processing 2015-08-18
# Processing 2015-08-19
# Processing 2015-08-20
# Processing 2015-08-21
# Processing 2015-08-22
# Processing 2015-08-23
# Processing 2015-08-24
# Processing 2015-08-25
# Processing 2015-08-26
# Processing 2015-08-27
# Processing 2015-08-28
# Processing 2015-08-29
# Processing 2015-08-30
# Processing 2015-08-31
# Processing 2015-09-01
# Processing 2015-09-02
# Processing 2015-09-03
# Processing 2015-09-04
# Processing 2015-09-05
# Processing 2015-09-06
# Processing 2015-09-07
# Processing 2015-09-08
# Processing 2015-09-09
# Processing 2015-09-10
# Processing 2015-09-11
# Processing 2015-09-12
# Processing 2015-09-13
# Processing 2015-09-14
# Processing 2015-09-15
# Processing 2015-09-16
# Processing 2015-09-17
# Processing 2015-09-18
# Processing 2015-09-19
# Processing 2015-09-20
# Processing 2015-09-21
# Processing 2015-09-22
# Processing 2015-09-23
# Processing 2015-09-24
# Processing 2015-09-25
# Processing 2015-09-26
# Processing 2015-09-27
# Processing 2015-09-28
# Processing 2015-09-29
# Processing 2015-09-30
# Processing 2015-10-01
# Processing 2015-10-02
# Processing 2015-10-03
# Processing 2015-10-04
# Processing 2015-10-05
# Processing 2015-10-06
# Processing 2015-10-07
# Processing 2015-10-08
# Processing 2015-10-09
# Processing 2015-10-10
# Processing 2015-10-11
# Processing 2015-10-12
# Processing 2015-10-13
# Processing 2015-10-14
# Processing 2015-10-15
# Processing 2015-10-16
# Processing 2015-10-17
# Processing 2015-10-18
# Processing 2015-10-19
# Processing 2015-10-20
# Processing 2015-10-21
# Processing 2015-10-22
# Processing 2015-10-23
# Processing 2015-10-24
# Processing 2015-10-25
# Processing 2015-10-26
# Processing 2015-10-27
# Processing 2015-10-28
# Processing 2015-10-29
# Processing 2015-10-30
# Processing 2015-10-31
# Processing 2015-11-01
# Processing 2015-11-02
# Processing 2015-11-03
# Processing 2015-11-04
# Processing 2015-11-05
# Processing 2015-11-06
# Processing 2015-11-07
# Processing 2015-11-08
# Processing 2015-11-09
# Processing 2015-11-10
# Processing 2015-11-11
# Processing 2015-11-12
# Processing 2015-11-13
# Processing 2015-11-14
# Processing 2015-11-15
# Processing 2015-11-16
# Processing 2015-11-17
# Processing 2015-11-18
# Processing 2015-11-19
# Processing 2015-11-20
# Processing 2015-11-21
# Processing 2015-11-22
# Processing 2015-11-23
# Processing 2015-11-24
# Processing 2015-11-25
# Processing 2015-11-26
# Processing 2015-11-27
# Processing 2015-11-28
# Processing 2015-11-29
# Processing 2015-11-30
# Processing 2015-12-01
# Processing 2015-12-02
# Processing 2015-12-03
# Processing 2015-12-04
# Processing 2015-12-05
# Processing 2015-12-06
# Processing 2015-12-07
# Processing 2015-12-08
# Processing 2015-12-09
# Processing 2015-12-10
# Processing 2015-12-11
# Processing 2015-12-12
# Processing 2015-12-13
# Processing 2015-12-14
# Processing 2015-12-15
# Processing 2015-12-16
# Processing 2015-12-17
# Processing 2015-12-18
# Processing 2015-12-19
# Processing 2015-12-20
# Processing 2015-12-21
# Processing 2015-12-22
# Processing 2015-12-23
# Processing 2015-12-24
# Processing 2015-12-25
# Processing 2015-12-26
# Processing 2015-12-27
# Processing 2015-12-28
# Processing 2015-12-29
# Processing 2015-12-30
# Processing 2015-12-31

# %% [markdown]
# ## Part 4: Compile Panels into a Movie
# After creating all of the panels, stitch them together into a movie using moviepy:

# %%
# make a list of files for each movie panel


# sort the panels

# %%
# set the frames per second
fps = 10

# use the ImageSequenceClip module to set up the clip


# write the video to a file
clip.write_videofile('C:\\Users\\Daniel\\Desktop\\CS185CMovie')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[260], line 5
#       2 fps = 10
#       4 # use the ImageSequenceClip module to set up the clip
# ----> 5 clip.moviepy.video.io.ImageSequenceClip.ImageSequenceClip(file_path_list, fps=fps)
#       7 # write the video to a file
#       8 clip.write_videofile('C:\\Users\\Daniel\\Desktop\\CS185CMovie')
#
# NameError: name 'clip' is not defined

# %% [markdown]
# ## Part 5: Interpret Features in the Movie
# A movie gives a good visualization of the physical processes occurring in a model. Describe one feature you see in the movie and relate it to an oceanographic feature. It could be a feature discussed in class or another feature you noticed and researched on your own.
#
# Answer: *Enter your description here*
